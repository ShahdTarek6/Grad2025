# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ffZkX9TjuFdKIrPjNcjL")
project = rf.workspace("page-oven").project("solar-daptx")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 3.1 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to solar-2 in yolov8:: 100%|██████████| 7400/7400 [00:00<00:00, 7595.05it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 19.7 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO,RTDETR
import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'
#os.environ['TORCH_USE_CUDA_DSA']='True'

# with tf.device('/GPU:0'):
if __name__ == '__main__':
    

    model = YOLO(r"yolov9c.pt")
    
    results = model.train(data=r"/kaggle/input/ddddddd/data.yaml", epochs=100, imgsz=640,device=0,batch=16,name="top_3")
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.0/871.0 kB 13.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ffZkX9TjuFdKIrPjNcjL")
project = rf.workspace("page-oven").project("solar-daptx")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 2.0 MB/s eta 0:00:00a 0:00:01
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to solar-2 in yolov9:: 100%|██████████| 7400/7400 [00:01<00:00, 7302.39it/s]

# %%
from ultralytics import YOLO,RTDETR
import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'
#os.environ['TORCH_USE_CUDA_DSA']='True'

# with tf.device('/GPU:0'):
if __name__ == '__main__':
    

    model = YOLO(r"yolov8n.pt")
    
    results = model.train(data=r"/kaggle/input/ddddddd/data.yaml", epochs=100, imgsz=640,device=0,batch=16,name="top_3")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 123MB/s]
# Ultralytics 8.3.11 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO,RTDETR
import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'
#os.environ['TORCH_USE_CUDA_DSA']='True'

# with tf.device('/GPU:0'):
if __name__ == '__main__':
    

    model = YOLO(r"yolo11m.pt")
    
    results = model.train(data=r"/kaggle/input/ddddddd/data.yaml", epochs=100, imgsz=640,device=0,batch=16,name="top_3")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 42.3MB/s]
# Ultralytics 8.3.12 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
