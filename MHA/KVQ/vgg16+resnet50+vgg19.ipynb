# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

# %% [markdown]
# # PRE PROCESSING

# %%
DATA_PATH = '../input/infrared-solar-modules/2020-02-14_InfraredSolarModules/InfraredSolarModules'
METADATA_PATH = os.path.join(DATA_PATH, 'module_metadata.json')

# %%
df = pd.read_json(METADATA_PATH, orient='index').sort_index()
df['image_filepath'] = df.image_filepath.apply(lambda x: os.path.join(DATA_PATH, x))
df
# Out:
#                                           image_filepath   anomaly_class
# 0      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 1      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 2      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 3      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 4      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# ...                                                  ...             ...
# 19995  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19996  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19997  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19998  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19999  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
#
# [20000 rows x 2 columns]

# %%
# Get unique values and their frequency
unique_values = df['anomaly_class'].value_counts()
print("\nUnique values and their frequency:")
print(unique_values)

# Set the figure size
plt.figure(figsize=(15, 6))

# Plot the bar chart
plt.bar(unique_values.index, unique_values.values)

# Set labels and title

plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.title('Frequency of Unique Values in Column')

# Show the plot
plt.show()
# Out:
# Unique values and their frequency:
# anomaly_class
# No-Anomaly        10000
# Cell               1877
# Vegetation         1639
# Diode              1499
# Cell-Multi         1288
# Shadowing          1056
# Cracking            940
# Offline-Module      827
# Hot-Spot            249
# Hot-Spot-Multi      246
# Soiling             204
# Diode-Multi         175
# Name: count, dtype: int64

# %%
# Get unique anomaly classes
unique_classes = df['anomaly_class'].unique()

# Plot the sampled images
plt.figure(figsize=(20, 20))

for i, class_name in enumerate(unique_classes, start=1):
    # Sample one image for each class
    sample = df[df['anomaly_class'] == class_name].sample(n=1).iloc[0]
    
    image = cv2.imread(sample['image_filepath'], 0)
    
    plt.subplot(6, 6, i)
    plt.imshow(image, cmap='inferno')
    plt.title(class_name)
    plt.axis('off')

plt.show()

# %% [markdown]
# **Splitting images based on module properties**
#
# As mentioned in readme of the dataset, the classes Hot-spot and Hot-spot Multi are anomalies from Thin film modules. These types of solar panels are less used in the industry when compared to (monocrystalline or polycrystalline) silicon modules and work completely different. But neither in Raptor maps github repository or in the dataset paper there is information about how many modules belong to the crystalline type and how much to the thin film type in the No-Anomaly class.

# %%
crystal_df = df.query('anomaly_class != ("Hot-Spot", "Hot-Spot-Multi")')
crystal_df
# Out:
#                                           image_filepath   anomaly_class
# 0      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 1      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 2      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 3      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 4      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# ...                                                  ...             ...
# 19995  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19996  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19997  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19998  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19999  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
#
# [19505 rows x 2 columns]

# %%
thin_film_df = df.query('anomaly_class == ("Hot-Spot", "Hot-Spot-Multi")')
thin_film_df
# Out:
#                                          image_filepath   anomaly_class
# 6722  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6723  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6724  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6725  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6726  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# ...                                                 ...             ...
# 8152  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8153  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8154  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8155  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8156  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
#
# [495 rows x 2 columns]

# %% [markdown]
# **MODEL FOR PREDICTION**

# %%
crystal_df['image_filepath']
# Out:
# 0        ../input/infrared-solar-modules/2020-02-14_Inf...
# 1        ../input/infrared-solar-modules/2020-02-14_Inf...
# 2        ../input/infrared-solar-modules/2020-02-14_Inf...
# 3        ../input/infrared-solar-modules/2020-02-14_Inf...
# 4        ../input/infrared-solar-modules/2020-02-14_Inf...
#                                ...
# 19995    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19996    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19997    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19998    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19999    ../input/infrared-solar-modules/2020-02-14_Inf...
# Name: image_filepath, Length: 19505, dtype: object

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(crystal_df, train_size=0.8, shuffle=True, random_state=1)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
import tensorflow as tf  # Import TensorFlow

train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
# Out:
# Found 12484 validated image filenames belonging to 10 classes.
# Found 3120 validated image filenames belonging to 10 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3901 validated image filenames belonging to 10 classes.

# %% [markdown]
# # RESNET 50

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Concatenate, LayerNormalization, MultiHeadAttention, Dropout
from tensorflow.keras.models import Model

# Load VGG16 model for Query (Q) without the top classification layer
vgg16_model = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Load VGG19 model for Key (K) without the top classification layer
vgg19_model = tf.keras.applications.VGG19(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Load ResNet50 model for Value (V) without the top classification layer
resnet50_model = tf.keras.applications.ResNet50(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Freeze layers if not fine-tuning
vgg16_model.trainable = False
vgg19_model.trainable = False
resnet50_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.layers import Lambda, Dense, MultiHeadAttention, Concatenate, Flatten

# Define input
inputs = tf.keras.Input(shape=(224, 224, 3))

# Extract features using each model
key_features = vgg16_model(inputs)
value_features = resnet50_model(inputs)
query_features =  vgg19_model(inputs)

# Align dimensions using Dense layers
key = Dense(512)(key_features)   # Match the dimensions
value = Dense(512)(value_features)
query = Dense(512)(query_features)

# Expand dimensions for compatibility with attention layer
key = Lambda(lambda x: tf.expand_dims(x, axis=1))(key)
value = Lambda(lambda x: tf.expand_dims(x, axis=1))(value)
query = Lambda(lambda x: tf.expand_dims(x, axis=1))(query)

# Define MHA with 8 heads
mha_layer = MultiHeadAttention(num_heads=8, key_dim=512)
attention_output = mha_layer(query=query, key=key, value=value)

# Reshape the attention output to match the rank of other features
attention_output = Lambda(lambda x: tf.squeeze(x, axis=1))(attention_output)

# Concatenate the output with the initial input features
concat_features = Concatenate()([attention_output, key_features, value_features, query_features])

# Add custom classification layers
x = Dense(128, activation='relu')(concat_features)
x = Dense(50, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

# Define final model
model = tf.keras.Model(inputs, outputs)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Lambda, Dense, MultiHeadAttention, Concatenate, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, precision_score, recall_score
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report, precision_score, recall_score
import numpy as np

# Define ModelCheckpoint to save the best model
# Define ModelCheckpoint callback to save the best model
checkpoint_callback = ModelCheckpoint(
    "best_model.keras",  # Changed to .keras
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)


# Define EarlyStopping to stop training when validation accuracy stops improving
early_stopping_callback = EarlyStopping(
    monitor="val_accuracy",
    patience=30,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restores the best weights after stopping
    verbose=1
)

# Train the model with early stopping
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=200,
    batch_size=32,
    callbacks=[checkpoint_callback, early_stopping_callback]
)

# Load the best model after training
# Load the best model after training
model.load_weights("best_model.keras")


# Evaluate on test set
results = model.evaluate(test_images, verbose=0)
print(f"Test Loss: {results[0]:.4f}, Test Accuracy: {results[1] * 100:.2f}%")

# Get predictions for the test set
y_pred_prob = model.predict(test_images)
y_pred_labels = np.argmax(y_pred_prob, axis=1)
y_true_labels = test_images.classes

# Calculate precision, recall, and other classification metrics
print("\nClassification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=test_images.class_indices.keys()))

# Precision and recall as separate metrics
precision = precision_score(y_true_labels, y_pred_labels, average="weighted")
recall = recall_score(y_true_labels, y_pred_labels, average="weighted")
print(f"Weighted Precision: {precision:.4f}")
print(f"Weighted Recall: {recall:.4f}")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.4331 - loss: 1.8008
# Epoch 1: val_accuracy improved from -inf to 0.58301, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 127s 266ms/step - accuracy: 0.4333 - loss: 1.8002 - val_accuracy: 0.5830 - val_loss: 1.3396
# Epoch 2/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5994 - loss: 1.2783
# Epoch 2: val_accuracy improved from 0.58301 to 0.64423, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.5995 - loss: 1.2782 - val_accuracy: 0.6442 - val_loss: 1.1813
# Epoch 3/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6426 - loss: 1.1394
# Epoch 3: val_accuracy improved from 0.64423 to 0.67340, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6427 - loss: 1.1393 - val_accuracy: 0.6734 - val_loss: 1.0773
# Epoch 4/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6793 - loss: 1.0388
# Epoch 4: val_accuracy improved from 0.67340 to 0.67692, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6793 - loss: 1.0388 - val_accuracy: 0.6769 - val_loss: 1.0342
# Epoch 5/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6872 - loss: 1.0012
# Epoch 5: val_accuracy improved from 0.67692 to 0.69359, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6872 - loss: 1.0011 - val_accuracy: 0.6936 - val_loss: 0.9758
# Epoch 6/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7044 - loss: 0.9315
# Epoch 7: val_accuracy improved from 0.69872 to 0.70160, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7044 - loss: 0.9314 - val_accuracy: 0.7016 - val_loss: 0.9350
# Epoch 8/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7236 - loss: 0.8823
# Epoch 8: val_accuracy improved from 0.70160 to 0.71218, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7236 - loss: 0.8823 - val_accuracy: 0.7122 - val_loss: 0.9162
# Epoch 9/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7258 - loss: 0.8631
# Epoch 9: val_accuracy improved from 0.71218 to 0.72019, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7258 - loss: 0.8631 - val_accuracy: 0.7202 - val_loss: 0.8932
# Epoch 10/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7302 - loss: 0.8462
# Epoch 10: val_accuracy improved from 0.72019 to 0.72083, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7302 - loss: 0.8462 - val_accuracy: 0.7208 - val_loss: 0.8652
# Epoch 11/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7332 - loss: 0.8392
# Epoch 11: val_accuracy improved from 0.72083 to 0.72660, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7332 - loss: 0.8391 - val_accuracy: 0.7266 - val_loss: 0.8495
# Epoch 12/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7454 - loss: 0.7999
# Epoch 12: val_accuracy improved from 0.72660 to 0.73077, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7454 - loss: 0.7999 - val_accuracy: 0.7308 - val_loss: 0.8351
# Epoch 13/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7472 - loss: 0.7904
# Epoch 13: val_accuracy improved from 0.73077 to 0.73333, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7472 - loss: 0.7904 - val_accuracy: 0.7333 - val_loss: 0.8218
# Epoch 14/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7503 - loss: 0.7692
# Epoch 14: val_accuracy did not improve from 0.73333
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7503 - loss: 0.7692 - val_accuracy: 0.7272 - val_loss: 0.8222
# Epoch 15/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7577 - loss: 0.7485
# Epoch 15: val_accuracy improved from 0.73333 to 0.73878, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7577 - loss: 0.7485 - val_accuracy: 0.7388 - val_loss: 0.8127
# Epoch 16/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7569 - loss: 0.7611
# Epoch 16: val_accuracy did not improve from 0.73878
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7569 - loss: 0.7610 - val_accuracy: 0.7359 - val_loss: 0.8114
# Epoch 17/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7549 - loss: 0.7508
# Epoch 17: val_accuracy improved from 0.73878 to 0.73910, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7549 - loss: 0.7508 - val_accuracy: 0.7391 - val_loss: 0.8001
# Epoch 18/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7613 - loss: 0.7392
# Epoch 18: val_accuracy did not improve from 0.73910
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7613 - loss: 0.7392 - val_accuracy: 0.7372 - val_loss: 0.7944
# Epoch 19/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7621 - loss: 0.7394
# Epoch 19: val_accuracy improved from 0.73910 to 0.74103, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7621 - loss: 0.7394 - val_accuracy: 0.7410 - val_loss: 0.7917
# Epoch 20/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7662 - loss: 0.7134
# Epoch 20: val_accuracy did not improve from 0.74103
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7662 - loss: 0.7134 - val_accuracy: 0.7404 - val_loss: 0.7859
# Epoch 21/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7710 - loss: 0.6990
# Epoch 21: val_accuracy did not improve from 0.74103
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7709 - loss: 0.6991 - val_accuracy: 0.7404 - val_loss: 0.7922
# Epoch 22/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7763 - loss: 0.6823
# Epoch 22: val_accuracy improved from 0.74103 to 0.74615, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7763 - loss: 0.6824 - val_accuracy: 0.7462 - val_loss: 0.7795
# Epoch 23/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7797 - loss: 0.6899
# Epoch 23: val_accuracy improved from 0.74615 to 0.74679, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7797 - loss: 0.6899 - val_accuracy: 0.7468 - val_loss: 0.7780
# Epoch 24/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7894 - loss: 0.6636
# Epoch 24: val_accuracy improved from 0.74679 to 0.74744, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7894 - loss: 0.6636 - val_accuracy: 0.7474 - val_loss: 0.7677
# Epoch 25/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7746 - loss: 0.6762
# Epoch 25: val_accuracy improved from 0.74744 to 0.74936, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7746 - loss: 0.6762 - val_accuracy: 0.7494 - val_loss: 0.7617
# Epoch 26/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7824 - loss: 0.6606
# Epoch 26: val_accuracy did not improve from 0.74936
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7824 - loss: 0.6607 - val_accuracy: 0.7471 - val_loss: 0.7692
# Epoch 27/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7737 - loss: 0.6780
# Epoch 27: val_accuracy improved from 0.74936 to 0.75224, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7737 - loss: 0.6780 - val_accuracy: 0.7522 - val_loss: 0.7624
# Epoch 28/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7869 - loss: 0.6425
# Epoch 28: val_accuracy improved from 0.75224 to 0.76122, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7869 - loss: 0.6425 - val_accuracy: 0.7612 - val_loss: 0.7526
# Epoch 29/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7815 - loss: 0.6412
# Epoch 29: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7815 - loss: 0.6412 - val_accuracy: 0.7574 - val_loss: 0.7503
# Epoch 30/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7914 - loss: 0.6442
# Epoch 30: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7914 - loss: 0.6442 - val_accuracy: 0.7538 - val_loss: 0.7450
# Epoch 31/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7872 - loss: 0.6326
# Epoch 31: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7872 - loss: 0.6326 - val_accuracy: 0.7494 - val_loss: 0.7624
# Epoch 32/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7975 - loss: 0.6196
# Epoch 32: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7975 - loss: 0.6196 - val_accuracy: 0.7567 - val_loss: 0.7456
# Epoch 33/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7956 - loss: 0.6169
# Epoch 33: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7956 - loss: 0.6169 - val_accuracy: 0.7612 - val_loss: 0.7385
# Epoch 34/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7950 - loss: 0.6165
# Epoch 34: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7950 - loss: 0.6165 - val_accuracy: 0.7574 - val_loss: 0.7407
# Epoch 35/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7939 - loss: 0.6232
# Epoch 35: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7939 - loss: 0.6232 - val_accuracy: 0.7593 - val_loss: 0.7473
# Epoch 36/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7997 - loss: 0.6116
# Epoch 36: val_accuracy did not improve from 0.76122
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7997 - loss: 0.6116 - val_accuracy: 0.7526 - val_loss: 0.7444
# Epoch 37/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7998 - loss: 0.6108
# Epoch 37: val_accuracy improved from 0.76122 to 0.77147, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7999 - loss: 0.6108 - val_accuracy: 0.7715 - val_loss: 0.7290
# Epoch 38/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8080 - loss: 0.5884
# Epoch 38: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8080 - loss: 0.5884 - val_accuracy: 0.7638 - val_loss: 0.7382
# Epoch 39/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8164 - loss: 0.5745
# Epoch 39: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8164 - loss: 0.5746 - val_accuracy: 0.7545 - val_loss: 0.7415
# Epoch 40/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8072 - loss: 0.5769
# Epoch 40: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8072 - loss: 0.5769 - val_accuracy: 0.7667 - val_loss: 0.7255
# Epoch 41/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8104 - loss: 0.5730
# Epoch 41: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8104 - loss: 0.5730 - val_accuracy: 0.7606 - val_loss: 0.7348
# Epoch 42/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8201 - loss: 0.5615
# Epoch 42: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8201 - loss: 0.5615 - val_accuracy: 0.7657 - val_loss: 0.7243
# Epoch 43/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8166 - loss: 0.5610
# Epoch 44: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8200 - loss: 0.5607 - val_accuracy: 0.7635 - val_loss: 0.7393
# Epoch 45/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8188 - loss: 0.5455
# Epoch 45: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8188 - loss: 0.5455 - val_accuracy: 0.7625 - val_loss: 0.7388
# Epoch 46/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8252 - loss: 0.5424
# Epoch 46: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8251 - loss: 0.5424 - val_accuracy: 0.7712 - val_loss: 0.7085
# Epoch 47/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8281 - loss: 0.5394
# Epoch 47: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8281 - loss: 0.5394 - val_accuracy: 0.7654 - val_loss: 0.7176
# Epoch 48/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8241 - loss: 0.5308
# Epoch 48: val_accuracy improved from 0.77147 to 0.77404, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8241 - loss: 0.5308 - val_accuracy: 0.7740 - val_loss: 0.7121
# Epoch 49/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8292 - loss: 0.5279
# Epoch 49: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8292 - loss: 0.5279 - val_accuracy: 0.7699 - val_loss: 0.7158
# Epoch 50/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8248 - loss: 0.5347
# Epoch 50: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8248 - loss: 0.5347 - val_accuracy: 0.7644 - val_loss: 0.7198
# Epoch 51/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8275 - loss: 0.5220
# Epoch 51: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8275 - loss: 0.5220 - val_accuracy: 0.7657 - val_loss: 0.7176
# Epoch 52/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8318 - loss: 0.5090
# Epoch 52: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8318 - loss: 0.5090 - val_accuracy: 0.7667 - val_loss: 0.7122
# Epoch 53/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8346 - loss: 0.5141
# Epoch 53: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8346 - loss: 0.5141 - val_accuracy: 0.7657 - val_loss: 0.7182
# Epoch 54/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8267 - loss: 0.5190
# Epoch 54: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8267 - loss: 0.5189 - val_accuracy: 0.7663 - val_loss: 0.7100
# Epoch 55/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8406 - loss: 0.4882
# Epoch 55: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8406 - loss: 0.4883 - val_accuracy: 0.7708 - val_loss: 0.7032
# Epoch 56/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8403 - loss: 0.4919
# Epoch 56: val_accuracy did not improve from 0.77404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8403 - loss: 0.4919 - val_accuracy: 0.7667 - val_loss: 0.7186
# Epoch 57/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8350 - loss: 0.4935
# Epoch 57: val_accuracy improved from 0.77404 to 0.77500, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8350 - loss: 0.4935 - val_accuracy: 0.7750 - val_loss: 0.7209
# Epoch 58/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8454 - loss: 0.4865
# Epoch 58: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8454 - loss: 0.4865 - val_accuracy: 0.7715 - val_loss: 0.7224
# Epoch 59/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8393 - loss: 0.4843
# Epoch 59: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8393 - loss: 0.4843 - val_accuracy: 0.7660 - val_loss: 0.7217
# Epoch 60/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8489 - loss: 0.4719
# Epoch 60: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8489 - loss: 0.4719 - val_accuracy: 0.7683 - val_loss: 0.7020
# Epoch 61/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8428 - loss: 0.4735
# Epoch 61: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8428 - loss: 0.4735 - val_accuracy: 0.7667 - val_loss: 0.7069
# Epoch 62/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8451 - loss: 0.4689
# Epoch 62: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8451 - loss: 0.4689 - val_accuracy: 0.7708 - val_loss: 0.7161
# Epoch 63/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8491 - loss: 0.4656
# Epoch 63: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8491 - loss: 0.4656 - val_accuracy: 0.7724 - val_loss: 0.7034
# Epoch 64/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8518 - loss: 0.4503
# Epoch 64: val_accuracy did not improve from 0.77500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8518 - loss: 0.4504 - val_accuracy: 0.7683 - val_loss: 0.7445
# Epoch 65/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8510 - loss: 0.4526
# Epoch 65: val_accuracy improved from 0.77500 to 0.77596, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8510 - loss: 0.4526 - val_accuracy: 0.7760 - val_loss: 0.7034
# Epoch 66/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8542 - loss: 0.4478
# Epoch 66: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8542 - loss: 0.4478 - val_accuracy: 0.7696 - val_loss: 0.7227
# Epoch 67/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8550 - loss: 0.4400
# Epoch 67: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8550 - loss: 0.4400 - val_accuracy: 0.7753 - val_loss: 0.7006
# Epoch 68/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8596 - loss: 0.4384
# Epoch 68: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8596 - loss: 0.4384 - val_accuracy: 0.7724 - val_loss: 0.7117
# Epoch 69/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8594 - loss: 0.4351
# Epoch 69: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8594 - loss: 0.4351 - val_accuracy: 0.7593 - val_loss: 0.7246
# Epoch 70/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8539 - loss: 0.4405
# Epoch 70: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8539 - loss: 0.4405 - val_accuracy: 0.7731 - val_loss: 0.7243
# Epoch 71/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8599 - loss: 0.4361
# Epoch 71: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8599 - loss: 0.4361 - val_accuracy: 0.7731 - val_loss: 0.7070
# Epoch 72/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8625 - loss: 0.4293
# Epoch 72: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8625 - loss: 0.4293 - val_accuracy: 0.7715 - val_loss: 0.7006
# Epoch 73/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8662 - loss: 0.4155
# Epoch 73: val_accuracy did not improve from 0.77596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8662 - loss: 0.4156 - val_accuracy: 0.7692 - val_loss: 0.7122
# Epoch 74/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8644 - loss: 0.4168
# Epoch 74: val_accuracy improved from 0.77596 to 0.77788, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8644 - loss: 0.4168 - val_accuracy: 0.7779 - val_loss: 0.7154
# Epoch 75/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8662 - loss: 0.4092
# Epoch 75: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8662 - loss: 0.4092 - val_accuracy: 0.7679 - val_loss: 0.7087
# Epoch 76/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8659 - loss: 0.4086
# Epoch 76: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8659 - loss: 0.4086 - val_accuracy: 0.7702 - val_loss: 0.7356
# Epoch 77/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8680 - loss: 0.4065
# Epoch 77: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8680 - loss: 0.4065 - val_accuracy: 0.7740 - val_loss: 0.7076
# Epoch 78/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8740 - loss: 0.3972
# Epoch 78: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8740 - loss: 0.3972 - val_accuracy: 0.7660 - val_loss: 0.7312
# Epoch 79/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8690 - loss: 0.3984
# Epoch 79: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8690 - loss: 0.3984 - val_accuracy: 0.7635 - val_loss: 0.7147
# Epoch 80/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8732 - loss: 0.3904
# Epoch 80: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8732 - loss: 0.3904 - val_accuracy: 0.7644 - val_loss: 0.7191
# Epoch 81/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8743 - loss: 0.3945
# Epoch 81: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8743 - loss: 0.3945 - val_accuracy: 0.7731 - val_loss: 0.7207
# Epoch 82/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8778 - loss: 0.3909
# Epoch 82: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8778 - loss: 0.3909 - val_accuracy: 0.7702 - val_loss: 0.7407
# Epoch 83/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8738 - loss: 0.3871
# Epoch 83: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8738 - loss: 0.3871 - val_accuracy: 0.7699 - val_loss: 0.7215
# Epoch 84/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8769 - loss: 0.3875
# Epoch 84: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8769 - loss: 0.3875 - val_accuracy: 0.7670 - val_loss: 0.7373
# Epoch 85/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8825 - loss: 0.3734
# Epoch 85: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8825 - loss: 0.3734 - val_accuracy: 0.7683 - val_loss: 0.7468
# Epoch 86/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8793 - loss: 0.3716
# Epoch 86: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8793 - loss: 0.3716 - val_accuracy: 0.7625 - val_loss: 0.7316
# Epoch 87/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8810 - loss: 0.3665
# Epoch 87: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8810 - loss: 0.3665 - val_accuracy: 0.7660 - val_loss: 0.7372
# Epoch 88/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8810 - loss: 0.3677
# Epoch 88: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8810 - loss: 0.3677 - val_accuracy: 0.7670 - val_loss: 0.7246
# Epoch 89/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8840 - loss: 0.3551
# Epoch 89: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8839 - loss: 0.3552 - val_accuracy: 0.7689 - val_loss: 0.7384
# Epoch 90/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8850 - loss: 0.3615
# Epoch 90: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8850 - loss: 0.3615 - val_accuracy: 0.7670 - val_loss: 0.7254
# Epoch 91/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8858 - loss: 0.3510
# Epoch 91: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8858 - loss: 0.3510 - val_accuracy: 0.7625 - val_loss: 0.7377
# Epoch 92/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8857 - loss: 0.3548
# Epoch 92: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8857 - loss: 0.3548 - val_accuracy: 0.7657 - val_loss: 0.7547
# Epoch 93/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8878 - loss: 0.3517
# Epoch 93: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8878 - loss: 0.3517 - val_accuracy: 0.7673 - val_loss: 0.7406
# Epoch 94/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8887 - loss: 0.3469
# Epoch 94: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8887 - loss: 0.3469 - val_accuracy: 0.7689 - val_loss: 0.7531
# Epoch 95/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8978 - loss: 0.3305
# Epoch 95: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8978 - loss: 0.3305 - val_accuracy: 0.7567 - val_loss: 0.7517
# Epoch 96/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8895 - loss: 0.3491
# Epoch 96: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8895 - loss: 0.3491 - val_accuracy: 0.7683 - val_loss: 0.7509
# Epoch 97/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8949 - loss: 0.3382
# Epoch 97: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8949 - loss: 0.3382 - val_accuracy: 0.7692 - val_loss: 0.7619
# Epoch 98/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8961 - loss: 0.3340
# Epoch 98: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8961 - loss: 0.3340 - val_accuracy: 0.7715 - val_loss: 0.7464
# Epoch 99/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8970 - loss: 0.3170
# Epoch 99: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8970 - loss: 0.3170 - val_accuracy: 0.7654 - val_loss: 0.7718
# Epoch 100/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8990 - loss: 0.3247
# Epoch 100: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8990 - loss: 0.3247 - val_accuracy: 0.7590 - val_loss: 0.7633
# Epoch 101/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8978 - loss: 0.3213
# Epoch 101: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8978 - loss: 0.3213 - val_accuracy: 0.7676 - val_loss: 0.7533
# Epoch 102/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8990 - loss: 0.3208
# Epoch 102: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8990 - loss: 0.3208 - val_accuracy: 0.7625 - val_loss: 0.7716
# Epoch 103/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9023 - loss: 0.3156
# Epoch 103: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.9023 - loss: 0.3156 - val_accuracy: 0.7676 - val_loss: 0.7606
# Epoch 104/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9045 - loss: 0.3002
# Epoch 104: val_accuracy did not improve from 0.77788
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.9045 - loss: 0.3002 - val_accuracy: 0.7663 - val_loss: 0.7789
# Epoch 104: early stopping
# Restoring model weights from the end of the best epoch: 74.
# Test Loss: 0.7737, Test Accuracy: 76.06%
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 28s 199ms/step
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#           Cell       0.61      0.52      0.56       391
#     Cell-Multi       0.54      0.28      0.37       283
#       Cracking       0.64      0.80      0.71       186
#          Diode       0.79      0.81      0.80       300
#    Diode-Multi       0.82      0.42      0.55        43
#     No-Anomaly       0.84      0.96      0.90      1915
# Offline-Module       0.60      0.38      0.46       172
#      Shadowing       0.72      0.54      0.62       220
#        Soiling       0.30      0.30      0.30        30
#     Vegetation       0.67      0.66      0.67       361
#
#       accuracy                           0.76      3901
#      macro avg       0.65      0.57      0.59      3901
#   weighted avg       0.74      0.76      0.74      3901
#
# Weighted Precision: 0.7434
# Weighted Recall: 0.7606

# %%
print(" ")
