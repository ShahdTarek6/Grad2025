# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

# %% [markdown]
# # PRE PROCESSING

# %%
DATA_PATH = '../input/infrared-solar-modules/2020-02-14_InfraredSolarModules/InfraredSolarModules'
METADATA_PATH = os.path.join(DATA_PATH, 'module_metadata.json')

# %%
df = pd.read_json(METADATA_PATH, orient='index').sort_index()
df['image_filepath'] = df.image_filepath.apply(lambda x: os.path.join(DATA_PATH, x))
df
# Out:
#                                           image_filepath   anomaly_class
# 0      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 1      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 2      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 3      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 4      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# ...                                                  ...             ...
# 19995  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19996  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19997  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19998  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19999  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
#
# [20000 rows x 2 columns]

# %%
# Get unique values and their frequency
unique_values = df['anomaly_class'].value_counts()
print("\nUnique values and their frequency:")
print(unique_values)

# Set the figure size
plt.figure(figsize=(15, 6))

# Plot the bar chart
plt.bar(unique_values.index, unique_values.values)

# Set labels and title

plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.title('Frequency of Unique Values in Column')

# Show the plot
plt.show()
# Out:
# Unique values and their frequency:
# anomaly_class
# No-Anomaly        10000
# Cell               1877
# Vegetation         1639
# Diode              1499
# Cell-Multi         1288
# Shadowing          1056
# Cracking            940
# Offline-Module      827
# Hot-Spot            249
# Hot-Spot-Multi      246
# Soiling             204
# Diode-Multi         175
# Name: count, dtype: int64

# %%
# Get unique anomaly classes
unique_classes = df['anomaly_class'].unique()

# Plot the sampled images
plt.figure(figsize=(20, 20))

for i, class_name in enumerate(unique_classes, start=1):
    # Sample one image for each class
    sample = df[df['anomaly_class'] == class_name].sample(n=1).iloc[0]
    
    image = cv2.imread(sample['image_filepath'], 0)
    
    plt.subplot(6, 6, i)
    plt.imshow(image, cmap='inferno')
    plt.title(class_name)
    plt.axis('off')

plt.show()

# %% [markdown]
# **Splitting images based on module properties**
#
# As mentioned in readme of the dataset, the classes Hot-spot and Hot-spot Multi are anomalies from Thin film modules. These types of solar panels are less used in the industry when compared to (monocrystalline or polycrystalline) silicon modules and work completely different. But neither in Raptor maps github repository or in the dataset paper there is information about how many modules belong to the crystalline type and how much to the thin film type in the No-Anomaly class.

# %%
crystal_df = df.query('anomaly_class != ("Hot-Spot", "Hot-Spot-Multi")')
crystal_df
# Out:
#                                           image_filepath   anomaly_class
# 0      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 1      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 2      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 3      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 4      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# ...                                                  ...             ...
# 19995  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19996  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19997  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19998  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19999  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
#
# [19505 rows x 2 columns]

# %%
thin_film_df = df.query('anomaly_class == ("Hot-Spot", "Hot-Spot-Multi")')
thin_film_df
# Out:
#                                          image_filepath   anomaly_class
# 6722  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6723  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6724  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6725  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6726  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# ...                                                 ...             ...
# 8152  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8153  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8154  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8155  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8156  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
#
# [495 rows x 2 columns]

# %% [markdown]
# **MODEL FOR PREDICTION**

# %%
crystal_df['image_filepath']
# Out:
# 0        ../input/infrared-solar-modules/2020-02-14_Inf...
# 1        ../input/infrared-solar-modules/2020-02-14_Inf...
# 2        ../input/infrared-solar-modules/2020-02-14_Inf...
# 3        ../input/infrared-solar-modules/2020-02-14_Inf...
# 4        ../input/infrared-solar-modules/2020-02-14_Inf...
#                                ...
# 19995    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19996    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19997    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19998    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19999    ../input/infrared-solar-modules/2020-02-14_Inf...
# Name: image_filepath, Length: 19505, dtype: object

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(crystal_df, train_size=0.8, shuffle=True, random_state=1)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
import tensorflow as tf  # Import TensorFlow

train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
# Out:
# Found 12484 validated image filenames belonging to 10 classes.
# Found 3120 validated image filenames belonging to 10 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3901 validated image filenames belonging to 10 classes.

# %% [markdown]
# # RESNET 50

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Concatenate, LayerNormalization, MultiHeadAttention, Dropout
from tensorflow.keras.models import Model

# Load VGG16 model for Query (Q) without the top classification layer
vgg16_model = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Load VGG19 model for Key (K) without the top classification layer
vgg19_model = tf.keras.applications.VGG19(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Load ResNet50 model for Value (V) without the top classification layer
resnet50_model = tf.keras.applications.ResNet50(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Freeze layers if not fine-tuning
vgg16_model.trainable = False
vgg19_model.trainable = False
resnet50_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.layers import Lambda, Dense, MultiHeadAttention, Concatenate, Flatten

# Define input
inputs = tf.keras.Input(shape=(224, 224, 3))

# Extract features using each model
key_features = vgg19_model(inputs)
value_features = resnet50_model(inputs)
query_features = vgg16_model(inputs)

# Align dimensions using Dense layers
key = Dense(512)(key_features)   # Match the dimensions
value = Dense(512)(value_features)
query = Dense(512)(query_features)

# Expand dimensions for compatibility with attention layer
key = Lambda(lambda x: tf.expand_dims(x, axis=1))(key)
value = Lambda(lambda x: tf.expand_dims(x, axis=1))(value)
query = Lambda(lambda x: tf.expand_dims(x, axis=1))(query)

# Define MHA with 8 heads
mha_layer = MultiHeadAttention(num_heads=8, key_dim=512)
attention_output = mha_layer(query=query, key=key, value=value)

# Reshape the attention output to match the rank of other features
attention_output = Lambda(lambda x: tf.squeeze(x, axis=1))(attention_output)

# Concatenate the output with the initial input features
concat_features = Concatenate()([attention_output, key_features, value_features, query_features])

# Add custom classification layers
x = Dense(128, activation='relu')(concat_features)
x = Dense(50, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

# Define final model
model = tf.keras.Model(inputs, outputs)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Lambda, Dense, MultiHeadAttention, Concatenate, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, precision_score, recall_score
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report, precision_score, recall_score
import numpy as np

# Define ModelCheckpoint to save the best model
# Define ModelCheckpoint callback to save the best model
checkpoint_callback = ModelCheckpoint(
    "best_model.keras",  # Changed to .keras
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)


# Define EarlyStopping to stop training when validation accuracy stops improving
early_stopping_callback = EarlyStopping(
    monitor="val_accuracy",
    patience=30,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restores the best weights after stopping
    verbose=1
)

# Train the model with early stopping
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=200,
    batch_size=32,
    callbacks=[checkpoint_callback, early_stopping_callback]
)

# Load the best model after training
# Load the best model after training
model.load_weights("best_model.keras")


# Evaluate on test set
results = model.evaluate(test_images, verbose=0)
print(f"Test Loss: {results[0]:.4f}, Test Accuracy: {results[1] * 100:.2f}%")

# Get predictions for the test set
y_pred_prob = model.predict(test_images)
y_pred_labels = np.argmax(y_pred_prob, axis=1)
y_true_labels = test_images.classes

# Calculate precision, recall, and other classification metrics
print("\nClassification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=test_images.class_indices.keys()))

# Precision and recall as separate metrics
precision = precision_score(y_true_labels, y_pred_labels, average="weighted")
recall = recall_score(y_true_labels, y_pred_labels, average="weighted")
print(f"Weighted Precision: {precision:.4f}")
print(f"Weighted Recall: {recall:.4f}")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.4850 - loss: 1.7008
# Epoch 1: val_accuracy improved from -inf to 0.57628, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 127s 266ms/step - accuracy: 0.4851 - loss: 1.7003 - val_accuracy: 0.5763 - val_loss: 1.3051
# Epoch 2/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6085 - loss: 1.2361
# Epoch 2: val_accuracy improved from 0.57628 to 0.65096, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.6086 - loss: 1.2360 - val_accuracy: 0.6510 - val_loss: 1.1233
# Epoch 3/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6566 - loss: 1.1122
# Epoch 3: val_accuracy improved from 0.65096 to 0.67308, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.6566 - loss: 1.1121 - val_accuracy: 0.6731 - val_loss: 1.0430
# Epoch 4/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6829 - loss: 1.0275
# Epoch 4: val_accuracy improved from 0.67308 to 0.68974, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6829 - loss: 1.0275 - val_accuracy: 0.6897 - val_loss: 1.0026
# Epoch 5/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6943 - loss: 0.9754
# Epoch 5: val_accuracy improved from 0.68974 to 0.69038, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.6943 - loss: 0.9753 - val_accuracy: 0.6904 - val_loss: 0.9562
# Epoch 6/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7107 - loss: 0.9155
# Epoch 6: val_accuracy improved from 0.69038 to 0.71186, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7107 - loss: 0.9155 - val_accuracy: 0.7119 - val_loss: 0.9175
# Epoch 7/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7166 - loss: 0.8874
# Epoch 7: val_accuracy improved from 0.71186 to 0.71571, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7166 - loss: 0.8874 - val_accuracy: 0.7157 - val_loss: 0.8922
# Epoch 8/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7187 - loss: 0.8815
# Epoch 8: val_accuracy did not improve from 0.71571
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7187 - loss: 0.8815 - val_accuracy: 0.7112 - val_loss: 0.8781
# Epoch 9/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7305 - loss: 0.8477
# Epoch 9: val_accuracy improved from 0.71571 to 0.72404, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.7305 - loss: 0.8477 - val_accuracy: 0.7240 - val_loss: 0.8715
# Epoch 10/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7357 - loss: 0.8230
# Epoch 10: val_accuracy did not improve from 0.72404
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7357 - loss: 0.8230 - val_accuracy: 0.7144 - val_loss: 0.8690
# Epoch 11/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7359 - loss: 0.8120
# Epoch 11: val_accuracy improved from 0.72404 to 0.72436, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7359 - loss: 0.8120 - val_accuracy: 0.7244 - val_loss: 0.8444
# Epoch 12/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7422 - loss: 0.7945
# Epoch 12: val_accuracy improved from 0.72436 to 0.73045, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7422 - loss: 0.7945 - val_accuracy: 0.7304 - val_loss: 0.8309
# Epoch 13/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7473 - loss: 0.8055
# Epoch 13: val_accuracy improved from 0.73045 to 0.73333, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.7473 - loss: 0.8055 - val_accuracy: 0.7333 - val_loss: 0.8165
# Epoch 14/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7444 - loss: 0.7865
# Epoch 14: val_accuracy improved from 0.73333 to 0.73686, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7444 - loss: 0.7865 - val_accuracy: 0.7369 - val_loss: 0.8157
# Epoch 15/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7504 - loss: 0.7526
# Epoch 15: val_accuracy improved from 0.73686 to 0.73846, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7504 - loss: 0.7526 - val_accuracy: 0.7385 - val_loss: 0.7979
# Epoch 16/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7606 - loss: 0.7273
# Epoch 16: val_accuracy did not improve from 0.73846
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7606 - loss: 0.7273 - val_accuracy: 0.7321 - val_loss: 0.8138
# Epoch 17/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7556 - loss: 0.7474
# Epoch 17: val_accuracy improved from 0.73846 to 0.74231, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7557 - loss: 0.7474 - val_accuracy: 0.7423 - val_loss: 0.7892
# Epoch 18/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7626 - loss: 0.7279
# Epoch 18: val_accuracy did not improve from 0.74231
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7626 - loss: 0.7279 - val_accuracy: 0.7420 - val_loss: 0.7788
# Epoch 19/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7685 - loss: 0.7077
# Epoch 19: val_accuracy did not improve from 0.74231
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.7685 - loss: 0.7077 - val_accuracy: 0.7346 - val_loss: 0.7994
# Epoch 20/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7737 - loss: 0.6960
# Epoch 20: val_accuracy improved from 0.74231 to 0.74519, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.7737 - loss: 0.6960 - val_accuracy: 0.7452 - val_loss: 0.7744
# Epoch 21/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7704 - loss: 0.6866
# Epoch 21: val_accuracy did not improve from 0.74519
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.7704 - loss: 0.6866 - val_accuracy: 0.7446 - val_loss: 0.7720
# Epoch 22/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7721 - loss: 0.6923
# Epoch 22: val_accuracy did not improve from 0.74519
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.7721 - loss: 0.6923 - val_accuracy: 0.7449 - val_loss: 0.7747
# Epoch 23/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7785 - loss: 0.6638
# Epoch 23: val_accuracy improved from 0.74519 to 0.75032, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 225ms/step - accuracy: 0.7785 - loss: 0.6638 - val_accuracy: 0.7503 - val_loss: 0.7594
# Epoch 24/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7818 - loss: 0.6679
# Epoch 24: val_accuracy did not improve from 0.75032
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7818 - loss: 0.6678 - val_accuracy: 0.7458 - val_loss: 0.7577
# Epoch 25/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7842 - loss: 0.6482
# Epoch 25: val_accuracy improved from 0.75032 to 0.75385, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7842 - loss: 0.6482 - val_accuracy: 0.7538 - val_loss: 0.7530
# Epoch 26/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7833 - loss: 0.6528
# Epoch 26: val_accuracy did not improve from 0.75385
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7833 - loss: 0.6528 - val_accuracy: 0.7487 - val_loss: 0.7566
# Epoch 27/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7871 - loss: 0.6456
# Epoch 27: val_accuracy improved from 0.75385 to 0.75481, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7871 - loss: 0.6456 - val_accuracy: 0.7548 - val_loss: 0.7454
# Epoch 28/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7824 - loss: 0.6583
# Epoch 28: val_accuracy improved from 0.75481 to 0.75545, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7825 - loss: 0.6582 - val_accuracy: 0.7554 - val_loss: 0.7378
# Epoch 29/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7953 - loss: 0.6233
# Epoch 29: val_accuracy improved from 0.75545 to 0.75737, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7953 - loss: 0.6233 - val_accuracy: 0.7574 - val_loss: 0.7426
# Epoch 30/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7968 - loss: 0.6210
# Epoch 30: val_accuracy improved from 0.75737 to 0.76090, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7968 - loss: 0.6210 - val_accuracy: 0.7609 - val_loss: 0.7333
# Epoch 31/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8003 - loss: 0.6090
# Epoch 31: val_accuracy did not improve from 0.76090
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8003 - loss: 0.6090 - val_accuracy: 0.7599 - val_loss: 0.7351
# Epoch 32/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7986 - loss: 0.6070
# Epoch 32: val_accuracy did not improve from 0.76090
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7986 - loss: 0.6070 - val_accuracy: 0.7503 - val_loss: 0.7562
# Epoch 33/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8032 - loss: 0.5893
# Epoch 33: val_accuracy did not improve from 0.76090
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8032 - loss: 0.5893 - val_accuracy: 0.7526 - val_loss: 0.7409
# Epoch 34/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8055 - loss: 0.5958
# Epoch 34: val_accuracy did not improve from 0.76090
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8055 - loss: 0.5958 - val_accuracy: 0.7574 - val_loss: 0.7350
# Epoch 35/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8071 - loss: 0.5747
# Epoch 35: val_accuracy did not improve from 0.76090
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8071 - loss: 0.5748 - val_accuracy: 0.7599 - val_loss: 0.7322
# Epoch 36/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8102 - loss: 0.5793
# Epoch 36: val_accuracy did not improve from 0.76090
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8102 - loss: 0.5793 - val_accuracy: 0.7580 - val_loss: 0.7349
# Epoch 37/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8081 - loss: 0.5736
# Epoch 37: val_accuracy improved from 0.76090 to 0.76346, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8081 - loss: 0.5736 - val_accuracy: 0.7635 - val_loss: 0.7254
# Epoch 38/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8089 - loss: 0.5746
# Epoch 38: val_accuracy improved from 0.76346 to 0.76410, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8089 - loss: 0.5746 - val_accuracy: 0.7641 - val_loss: 0.7182
# Epoch 39/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8194 - loss: 0.5565
# Epoch 39: val_accuracy improved from 0.76410 to 0.76699, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8193 - loss: 0.5566 - val_accuracy: 0.7670 - val_loss: 0.7236
# Epoch 40/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8239 - loss: 0.5349
# Epoch 40: val_accuracy did not improve from 0.76699
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8238 - loss: 0.5349 - val_accuracy: 0.7641 - val_loss: 0.7249
# Epoch 41/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8120 - loss: 0.5656
# Epoch 41: val_accuracy did not improve from 0.76699
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8121 - loss: 0.5656 - val_accuracy: 0.7622 - val_loss: 0.7318
# Epoch 42/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8175 - loss: 0.5499
# Epoch 42: val_accuracy did not improve from 0.76699
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8175 - loss: 0.5498 - val_accuracy: 0.7628 - val_loss: 0.7239
# Epoch 43/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8259 - loss: 0.5340
# Epoch 43: val_accuracy did not improve from 0.76699
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8259 - loss: 0.5340 - val_accuracy: 0.7631 - val_loss: 0.7145
# Epoch 44/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8310 - loss: 0.5150
# Epoch 44: val_accuracy improved from 0.76699 to 0.76891, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8310 - loss: 0.5151 - val_accuracy: 0.7689 - val_loss: 0.7116
# Epoch 45/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8279 - loss: 0.5231
# Epoch 45: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8279 - loss: 0.5231 - val_accuracy: 0.7663 - val_loss: 0.7156
# Epoch 46/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8339 - loss: 0.5114
# Epoch 46: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8338 - loss: 0.5114 - val_accuracy: 0.7660 - val_loss: 0.7108
# Epoch 47/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8291 - loss: 0.5260
# Epoch 47: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8291 - loss: 0.5260 - val_accuracy: 0.7679 - val_loss: 0.7125
# Epoch 48/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8309 - loss: 0.5152
# Epoch 48: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8309 - loss: 0.5152 - val_accuracy: 0.7660 - val_loss: 0.7243
# Epoch 49/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8391 - loss: 0.5025
# Epoch 49: val_accuracy improved from 0.76891 to 0.77147, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8391 - loss: 0.5025 - val_accuracy: 0.7715 - val_loss: 0.7151
# Epoch 50/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8377 - loss: 0.4958
# Epoch 50: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8377 - loss: 0.4958 - val_accuracy: 0.7712 - val_loss: 0.7105
# Epoch 51/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8391 - loss: 0.4860
# Epoch 51: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8391 - loss: 0.4860 - val_accuracy: 0.7686 - val_loss: 0.7280
# Epoch 52/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8358 - loss: 0.4932
# Epoch 52: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8358 - loss: 0.4932 - val_accuracy: 0.7683 - val_loss: 0.7185
# Epoch 53/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8417 - loss: 0.4844
# Epoch 53: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8417 - loss: 0.4844 - val_accuracy: 0.7692 - val_loss: 0.7082
# Epoch 54/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8445 - loss: 0.4787
# Epoch 54: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8445 - loss: 0.4787 - val_accuracy: 0.7676 - val_loss: 0.7205
# Epoch 55/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8445 - loss: 0.4716
# Epoch 55: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8445 - loss: 0.4716 - val_accuracy: 0.7692 - val_loss: 0.7259
# Epoch 56/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8466 - loss: 0.4687
# Epoch 56: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8466 - loss: 0.4687 - val_accuracy: 0.7603 - val_loss: 0.7210
# Epoch 57/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8506 - loss: 0.4545
# Epoch 57: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8506 - loss: 0.4545 - val_accuracy: 0.7715 - val_loss: 0.7087
# Epoch 58/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8539 - loss: 0.4583
# Epoch 58: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8539 - loss: 0.4583 - val_accuracy: 0.7657 - val_loss: 0.7085
# Epoch 59/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8486 - loss: 0.4666
# Epoch 59: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8486 - loss: 0.4666 - val_accuracy: 0.7683 - val_loss: 0.7149
# Epoch 60/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8450 - loss: 0.4643
# Epoch 60: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8450 - loss: 0.4643 - val_accuracy: 0.7696 - val_loss: 0.7234
# Epoch 61/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8526 - loss: 0.4544
# Epoch 61: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8526 - loss: 0.4544 - val_accuracy: 0.7673 - val_loss: 0.7282
# Epoch 62/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8569 - loss: 0.4383
# Epoch 62: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8569 - loss: 0.4383 - val_accuracy: 0.7663 - val_loss: 0.7175
# Epoch 63/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8603 - loss: 0.4381
# Epoch 63: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8603 - loss: 0.4381 - val_accuracy: 0.7628 - val_loss: 0.7161
# Epoch 64/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8568 - loss: 0.4321
# Epoch 64: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8568 - loss: 0.4321 - val_accuracy: 0.7676 - val_loss: 0.7164
# Epoch 65/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8584 - loss: 0.4364
# Epoch 65: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8584 - loss: 0.4364 - val_accuracy: 0.7679 - val_loss: 0.7084
# Epoch 66/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8592 - loss: 0.4288
# Epoch 66: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8592 - loss: 0.4288 - val_accuracy: 0.7679 - val_loss: 0.7184
# Epoch 67/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8651 - loss: 0.4208
# Epoch 67: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8651 - loss: 0.4208 - val_accuracy: 0.7635 - val_loss: 0.7536
# Epoch 68/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8711 - loss: 0.4049
# Epoch 68: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8710 - loss: 0.4049 - val_accuracy: 0.7628 - val_loss: 0.7216
# Epoch 69/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8657 - loss: 0.4129
# Epoch 69: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8657 - loss: 0.4129 - val_accuracy: 0.7715 - val_loss: 0.7291
# Epoch 70/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8707 - loss: 0.4026
# Epoch 70: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8707 - loss: 0.4027 - val_accuracy: 0.7625 - val_loss: 0.7466
# Epoch 71/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8681 - loss: 0.4071
# Epoch 71: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8681 - loss: 0.4071 - val_accuracy: 0.7654 - val_loss: 0.7383
# Epoch 72/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8717 - loss: 0.3978
# Epoch 72: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8717 - loss: 0.3978 - val_accuracy: 0.7667 - val_loss: 0.7311
# Epoch 73/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8694 - loss: 0.3997
# Epoch 73: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8694 - loss: 0.3997 - val_accuracy: 0.7679 - val_loss: 0.7221
# Epoch 74/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8767 - loss: 0.3803
# Epoch 74: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8766 - loss: 0.3804 - val_accuracy: 0.7667 - val_loss: 0.7302
# Epoch 75/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8786 - loss: 0.3778
# Epoch 75: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8786 - loss: 0.3778 - val_accuracy: 0.7689 - val_loss: 0.7322
# Epoch 76/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8801 - loss: 0.3733
# Epoch 76: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8801 - loss: 0.3733 - val_accuracy: 0.7599 - val_loss: 0.7356
# Epoch 77/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8791 - loss: 0.3867
# Epoch 77: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8791 - loss: 0.3867 - val_accuracy: 0.7619 - val_loss: 0.7321
# Epoch 78/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8801 - loss: 0.3687
# Epoch 78: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8801 - loss: 0.3687 - val_accuracy: 0.7593 - val_loss: 0.7434
# Epoch 79/200
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8781 - loss: 0.3845
# Epoch 79: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8781 - loss: 0.3845 - val_accuracy: 0.7696 - val_loss: 0.7384
# Epoch 79: early stopping
# Restoring model weights from the end of the best epoch: 49.
# Test Loss: 0.7563, Test Accuracy: 75.44%
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 27s 195ms/step
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#           Cell       0.56      0.55      0.56       391
#     Cell-Multi       0.48      0.29      0.36       283
#       Cracking       0.67      0.77      0.71       186
#          Diode       0.84      0.82      0.83       300
#    Diode-Multi       0.80      0.47      0.59        43
#     No-Anomaly       0.83      0.96      0.89      1915
# Offline-Module       0.63      0.32      0.42       172
#      Shadowing       0.78      0.45      0.57       220
#        Soiling       0.31      0.30      0.31        30
#     Vegetation       0.68      0.63      0.66       361
#
#       accuracy                           0.75      3901
#      macro avg       0.66      0.56      0.59      3901
#   weighted avg       0.74      0.75      0.74      3901
#
# Weighted Precision: 0.7386
# Weighted Recall: 0.7544

# %%
print(" ")
