# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

# %% [markdown]
# # PRE PROCESSING

# %%
DATA_PATH = '../input/infrared-solar-modules/2020-02-14_InfraredSolarModules/InfraredSolarModules'
METADATA_PATH = os.path.join(DATA_PATH, 'module_metadata.json')

# %%
df = pd.read_json(METADATA_PATH, orient='index').sort_index()
df['image_filepath'] = df.image_filepath.apply(lambda x: os.path.join(DATA_PATH, x))
df
# Out:
#                                           image_filepath   anomaly_class
# 0      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 1      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 2      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 3      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 4      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# ...                                                  ...             ...
# 19995  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19996  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19997  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19998  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19999  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
#
# [20000 rows x 2 columns]

# %%
# Get unique values and their frequency
unique_values = df['anomaly_class'].value_counts()
print("\nUnique values and their frequency:")
print(unique_values)

# Set the figure size
plt.figure(figsize=(15, 6))

# Plot the bar chart
plt.bar(unique_values.index, unique_values.values)

# Set labels and title

plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.title('Frequency of Unique Values in Column')

# Show the plot
plt.show()
# Out:
# Unique values and their frequency:
# anomaly_class
# No-Anomaly        10000
# Cell               1877
# Vegetation         1639
# Diode              1499
# Cell-Multi         1288
# Shadowing          1056
# Cracking            940
# Offline-Module      827
# Hot-Spot            249
# Hot-Spot-Multi      246
# Soiling             204
# Diode-Multi         175
# Name: count, dtype: int64

# %%
# Get unique anomaly classes
unique_classes = df['anomaly_class'].unique()

# Plot the sampled images
plt.figure(figsize=(20, 20))

for i, class_name in enumerate(unique_classes, start=1):
    # Sample one image for each class
    sample = df[df['anomaly_class'] == class_name].sample(n=1).iloc[0]
    
    image = cv2.imread(sample['image_filepath'], 0)
    
    plt.subplot(6, 6, i)
    plt.imshow(image, cmap='inferno')
    plt.title(class_name)
    plt.axis('off')

plt.show()

# %% [markdown]
# **Splitting images based on module properties**
#
# As mentioned in readme of the dataset, the classes Hot-spot and Hot-spot Multi are anomalies from Thin film modules. These types of solar panels are less used in the industry when compared to (monocrystalline or polycrystalline) silicon modules and work completely different. But neither in Raptor maps github repository or in the dataset paper there is information about how many modules belong to the crystalline type and how much to the thin film type in the No-Anomaly class.

# %%
crystal_df = df.query('anomaly_class != ("Hot-Spot", "Hot-Spot-Multi")')
crystal_df
# Out:
#                                           image_filepath   anomaly_class
# 0      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 1      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 2      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 3      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# 4      ../input/infrared-solar-modules/2020-02-14_Inf...  Offline-Module
# ...                                                  ...             ...
# 19995  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19996  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19997  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19998  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
# 19999  ../input/infrared-solar-modules/2020-02-14_Inf...      No-Anomaly
#
# [19505 rows x 2 columns]

# %%
thin_film_df = df.query('anomaly_class == ("Hot-Spot", "Hot-Spot-Multi")')
thin_film_df
# Out:
#                                          image_filepath   anomaly_class
# 6722  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6723  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6724  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6725  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# 6726  ../input/infrared-solar-modules/2020-02-14_Inf...        Hot-Spot
# ...                                                 ...             ...
# 8152  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8153  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8154  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8155  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
# 8156  ../input/infrared-solar-modules/2020-02-14_Inf...  Hot-Spot-Multi
#
# [495 rows x 2 columns]

# %% [markdown]
# **MODEL FOR PREDICTION**

# %%
crystal_df['image_filepath']
# Out:
# 0        ../input/infrared-solar-modules/2020-02-14_Inf...
# 1        ../input/infrared-solar-modules/2020-02-14_Inf...
# 2        ../input/infrared-solar-modules/2020-02-14_Inf...
# 3        ../input/infrared-solar-modules/2020-02-14_Inf...
# 4        ../input/infrared-solar-modules/2020-02-14_Inf...
#                                ...
# 19995    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19996    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19997    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19998    ../input/infrared-solar-modules/2020-02-14_Inf...
# 19999    ../input/infrared-solar-modules/2020-02-14_Inf...
# Name: image_filepath, Length: 19505, dtype: object

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(crystal_df, train_size=0.8, shuffle=True, random_state=1)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalAveragePooling2D
# Out:
# 2025-01-23 10:46:40.757877: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-23 10:46:40.757981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-23 10:46:40.893728: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import tensorflow as tf  # Import TensorFlow

train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
# Out:
# Found 12484 validated image filenames belonging to 10 classes.
# Found 3120 validated image filenames belonging to 10 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_filepath',
    y_col='anomaly_class',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3901 validated image filenames belonging to 10 classes.

# %% [markdown]
# # RESNET 50

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Concatenate, LayerNormalization, MultiHeadAttention, Dropout
from tensorflow.keras.models import Model

# Load VGG16 model for Query (Q) without the top classification layer
vgg16_model = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Load VGG19 model for Key (K) without the top classification layer
vgg19_model = tf.keras.applications.VGG19(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Load ResNet50 model for Value (V) without the top classification layer
resnet50_model = tf.keras.applications.ResNet50(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Freeze layers if not fine-tuning
vgg16_model.trainable = False
vgg19_model.trainable = False
resnet50_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.layers import Lambda, Dense, MultiHeadAttention, Concatenate, Flatten

# Define input
inputs = tf.keras.Input(shape=(224, 224, 3))

# Extract features using each model
key_features = resnet50_model(inputs)
value_features = vgg19_model(inputs)
query_features = vgg16_model(inputs)

# Align dimensions using Dense layers
key = Dense(512)(key_features)   # Match the dimensions
value = Dense(512)(value_features)
query = Dense(512)(query_features)

# Expand dimensions for compatibility with attention layer
key = Lambda(lambda x: tf.expand_dims(x, axis=1))(key)
value = Lambda(lambda x: tf.expand_dims(x, axis=1))(value)
query = Lambda(lambda x: tf.expand_dims(x, axis=1))(query)

# Define MHA with 8 heads
mha_layer = MultiHeadAttention(num_heads=8, key_dim=512)
attention_output = mha_layer(query=query, key=key, value=value)

# Reshape the attention output to match the rank of other features
attention_output = Lambda(lambda x: tf.squeeze(x, axis=1))(attention_output)

# Concatenate the output with the initial input features
concat_features = Concatenate()([attention_output, key_features, value_features, query_features])

# Add custom classification layers
x = Dense(128, activation='relu')(concat_features)
x = Dense(50, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

# Define final model
model = tf.keras.Model(inputs, outputs)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Lambda, Dense, MultiHeadAttention, Concatenate, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, precision_score, recall_score
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report, precision_score, recall_score
import numpy as np

# Define ModelCheckpoint to save the best model
# Define ModelCheckpoint callback to save the best model
checkpoint_callback = ModelCheckpoint(
    "best_model.keras",  # Changed to .keras
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)


# Define EarlyStopping to stop training when validation accuracy stops improving
early_stopping_callback = EarlyStopping(
    monitor="val_accuracy",
    patience=30,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restores the best weights after stopping
    verbose=1
)

# Train the model with early stopping
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=250,
    batch_size=32,
    callbacks=[checkpoint_callback, early_stopping_callback]
)

# Load the best model after training
# Load the best model after training
model.load_weights("best_model.keras")


# Evaluate on test set
results = model.evaluate(test_images, verbose=0)
print(f"Test Loss: {results[0]:.4f}, Test Accuracy: {results[1] * 100:.2f}%")

# Get predictions for the test set
y_pred_prob = model.predict(test_images)
y_pred_labels = np.argmax(y_pred_prob, axis=1)
y_true_labels = test_images.classes

# Calculate precision, recall, and other classification metrics
print("\nClassification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=test_images.class_indices.keys()))

# Precision and recall as separate metrics
precision = precision_score(y_true_labels, y_pred_labels, average="weighted")
recall = recall_score(y_true_labels, y_pred_labels, average="weighted")
print(f"Weighted Precision: {precision:.4f}")
print(f"Weighted Recall: {recall:.4f}")
# Out:
# Epoch 1/250
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-01-23 10:47:38.351661: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.63498, expected 3.85968
# 2025-01-23 10:47:38.351716: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.55784, expected 5.78254
# 2025-01-23 10:47:38.351726: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 6.61282, expected 5.83752
# 2025-01-23 10:47:38.351734: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.34499, expected 5.56968
# 2025-01-23 10:47:38.351742: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.25159, expected 5.47629
# 2025-01-23 10:47:38.351750: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.43964, expected 4.66434
# 2025-01-23 10:47:38.351758: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.54333, expected 5.76803
# 2025-01-23 10:47:38.351766: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.76049, expected 4.98519
# 2025-01-23 10:47:38.351774: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.33632, expected 4.56101
# 2025-01-23 10:47:38.351782: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 4.04081, expected 3.2655
# 2025-01-23 10:47:38.423122: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 10:47:38.423179: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 10:47:38.423188: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 10:47:38.423196: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 10:47:38.423203: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 10:47:38.423223: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2025-01-23 10:47:39.636051: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.63498, expected 3.85968
# 2025-01-23 10:47:39.636108: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.55784, expected 5.78254
# 2025-01-23 10:47:39.636124: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 6.61282, expected 5.83752
# 2025-01-23 10:47:39.636139: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.34499, expected 5.56968
# 2025-01-23 10:47:39.636150: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.25159, expected 5.47629
# 2025-01-23 10:47:39.636161: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.43964, expected 4.66434
# 2025-01-23 10:47:39.636172: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.54333, expected 5.76803
# 2025-01-23 10:47:39.636183: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.76049, expected 4.98519
# 2025-01-23 10:47:39.636193: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.33632, expected 4.56101
# 2025-01-23 10:47:39.636204: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 4.04081, expected 3.2655
# 2025-01-23 10:47:39.707909: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 10:47:39.707961: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 10:47:39.707977: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 10:47:39.707991: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 10:47:39.708001: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 10:47:39.708024: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#   1/391 ━━━━━━━━━━━━━━━━━━━━ 3:40:41 34s/step - accuracy: 0.0000e+00 - loss: 4.4720
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737629276.094477     106 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1737629276.151302     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 160/391 ━━━━━━━━━━━━━━━━━━━━ 40s 176ms/step - accuracy: 0.3038 - loss: 2.5226
# 2025-01-23 10:48:27.314055: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.46848, expected 3.68847
# 2025-01-23 10:48:27.314114: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 6.72762, expected 5.94762
# 2025-01-23 10:48:27.314124: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.00592, expected 5.22591
# 2025-01-23 10:48:27.314132: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 6.42362, expected 5.64362
# 2025-01-23 10:48:27.314140: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.34585, expected 4.56585
# 2025-01-23 10:48:27.314148: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.68756, expected 4.90755
# 2025-01-23 10:48:27.314156: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.73264, expected 4.95264
# 2025-01-23 10:48:27.314164: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.14339, expected 5.36338
# 2025-01-23 10:48:27.314172: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 6.14043, expected 5.36042
# 2025-01-23 10:48:27.314179: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.85686, expected 4.07686
# 2025-01-23 10:48:27.322967: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 10:48:27.322999: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 10:48:27.323008: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 10:48:27.323015: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 10:48:27.323022: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 10:48:27.323037: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2025-01-23 10:48:27.493360: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.46848, expected 3.68847
# 2025-01-23 10:48:27.493415: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 6.72762, expected 5.94762
# 2025-01-23 10:48:27.493425: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.00592, expected 5.22591
# 2025-01-23 10:48:27.493433: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 6.42362, expected 5.64362
# 2025-01-23 10:48:27.493441: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.34585, expected 4.56585
# 2025-01-23 10:48:27.493449: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.68756, expected 4.90755
# 2025-01-23 10:48:27.493457: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.73264, expected 4.95264
# 2025-01-23 10:48:27.493465: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.14339, expected 5.36338
# 2025-01-23 10:48:27.493473: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 6.14043, expected 5.36042
# 2025-01-23 10:48:27.493481: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.85686, expected 4.07686
# 2025-01-23 10:48:27.502355: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 10:48:27.502386: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 10:48:27.502395: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 10:48:27.502402: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 10:48:27.502409: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 10:48:27.502424: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.4144 - loss: 2.1032
# W0000 00:00:1737629359.056768     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 2025-01-23 10:49:38.654459: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.89842, expected 3.37692
# 2025-01-23 10:49:38.654516: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 3.13412, expected 2.61262
# 2025-01-23 10:49:38.654534: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 13: 3.08377, expected 2.56227
# 2025-01-23 10:49:38.654550: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 14: 4.1021, expected 3.5806
# 2025-01-23 10:49:38.654563: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 3.76539, expected 3.24388
# 2025-01-23 10:49:38.654575: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 4.19841, expected 3.6769
# 2025-01-23 10:49:38.654588: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 63: 3.88366, expected 3.36216
# 2025-01-23 10:49:38.654599: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 64: 3.84985, expected 3.32834
# 2025-01-23 10:49:38.654612: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 67: 3.61908, expected 3.09757
# 2025-01-23 10:49:38.654624: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 84: 3.73098, expected 3.20948
# 2025-01-23 10:49:38.690417: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[16,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 10:49:38.690467: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 10:49:38.690476: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 10:49:38.690484: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 10:49:38.690491: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 10:49:38.690508: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2025-01-23 10:49:39.291236: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.89842, expected 3.37692
# 2025-01-23 10:49:39.291289: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 3.13412, expected 2.61262
# 2025-01-23 10:49:39.291299: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 13: 3.08377, expected 2.56227
# 2025-01-23 10:49:39.291307: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 14: 4.1021, expected 3.5806
# 2025-01-23 10:49:39.291315: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 3.76539, expected 3.24388
# 2025-01-23 10:49:39.291323: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 4.19841, expected 3.6769
# 2025-01-23 10:49:39.291331: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 63: 3.88366, expected 3.36216
# 2025-01-23 10:49:39.291339: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 64: 3.84985, expected 3.32834
# 2025-01-23 10:49:39.291347: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 67: 3.61908, expected 3.09757
# 2025-01-23 10:49:39.291355: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 84: 3.73098, expected 3.20948
# 2025-01-23 10:49:39.327017: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[16,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 10:49:39.327054: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 10:49:39.327070: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 10:49:39.327086: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 10:49:39.327097: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 10:49:39.327117: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# Epoch 1: val_accuracy improved from -inf to 0.57244, saving model to best_model.keras
# W0000 00:00:1737629388.585536     109 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 149s 294ms/step - accuracy: 0.4147 - loss: 2.1022 - val_accuracy: 0.5724 - val_loss: 1.4088
# Epoch 2/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5892 - loss: 1.3636
# Epoch 2: val_accuracy improved from 0.57244 to 0.60353, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.5892 - loss: 1.3636 - val_accuracy: 0.6035 - val_loss: 1.2924
# Epoch 3/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6152 - loss: 1.2614
# Epoch 4: val_accuracy improved from 0.62917 to 0.65256, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6393 - loss: 1.1597 - val_accuracy: 0.6526 - val_loss: 1.1202
# Epoch 5/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6526 - loss: 1.1345
# Epoch 5: val_accuracy improved from 0.65256 to 0.65929, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6526 - loss: 1.1344 - val_accuracy: 0.6593 - val_loss: 1.0823
# Epoch 6/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6640 - loss: 1.0789
# Epoch 6: val_accuracy improved from 0.65929 to 0.67179, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6640 - loss: 1.0789 - val_accuracy: 0.6718 - val_loss: 1.0542
# Epoch 7/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6813 - loss: 1.0227
# Epoch 7: val_accuracy improved from 0.67179 to 0.68269, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6813 - loss: 1.0227 - val_accuracy: 0.6827 - val_loss: 1.0176
# Epoch 8/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6854 - loss: 0.9928
# Epoch 8: val_accuracy did not improve from 0.68269
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.6854 - loss: 0.9928 - val_accuracy: 0.6760 - val_loss: 1.0258
# Epoch 9/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6945 - loss: 0.9628
# Epoch 9: val_accuracy improved from 0.68269 to 0.69071, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6945 - loss: 0.9628 - val_accuracy: 0.6907 - val_loss: 0.9724
# Epoch 10/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6983 - loss: 0.9583
# Epoch 10: val_accuracy improved from 0.69071 to 0.70449, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.6983 - loss: 0.9583 - val_accuracy: 0.7045 - val_loss: 0.9500
# Epoch 11/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6994 - loss: 0.9396
# Epoch 11: val_accuracy did not improve from 0.70449
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.6995 - loss: 0.9396 - val_accuracy: 0.7016 - val_loss: 0.9423
# Epoch 12/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7093 - loss: 0.9205
# Epoch 12: val_accuracy improved from 0.70449 to 0.71571, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7093 - loss: 0.9205 - val_accuracy: 0.7157 - val_loss: 0.9191
# Epoch 13/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7072 - loss: 0.9344
# Epoch 13: val_accuracy did not improve from 0.71571
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.7072 - loss: 0.9343 - val_accuracy: 0.7115 - val_loss: 0.9083
# Epoch 14/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7151 - loss: 0.8992
# Epoch 14: val_accuracy did not improve from 0.71571
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.7151 - loss: 0.8992 - val_accuracy: 0.7096 - val_loss: 0.9102
# Epoch 15/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7246 - loss: 0.8571
# Epoch 15: val_accuracy improved from 0.71571 to 0.71667, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7246 - loss: 0.8571 - val_accuracy: 0.7167 - val_loss: 0.9008
# Epoch 16/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7345 - loss: 0.8358
# Epoch 16: val_accuracy improved from 0.71667 to 0.72212, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7345 - loss: 0.8359 - val_accuracy: 0.7221 - val_loss: 0.8716
# Epoch 17/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7311 - loss: 0.8232
# Epoch 17: val_accuracy did not improve from 0.72212
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7311 - loss: 0.8233 - val_accuracy: 0.7218 - val_loss: 0.8701
# Epoch 18/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7324 - loss: 0.8169
# Epoch 18: val_accuracy did not improve from 0.72212
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7324 - loss: 0.8169 - val_accuracy: 0.7173 - val_loss: 0.8741
# Epoch 19/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7336 - loss: 0.8109
# Epoch 19: val_accuracy improved from 0.72212 to 0.73077, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7336 - loss: 0.8109 - val_accuracy: 0.7308 - val_loss: 0.8545
# Epoch 20/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7444 - loss: 0.7887
# Epoch 20: val_accuracy improved from 0.73077 to 0.73397, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7443 - loss: 0.7887 - val_accuracy: 0.7340 - val_loss: 0.8525
# Epoch 21/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7412 - loss: 0.7897
# Epoch 21: val_accuracy did not improve from 0.73397
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7412 - loss: 0.7897 - val_accuracy: 0.7340 - val_loss: 0.8426
# Epoch 22/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7529 - loss: 0.7601
# Epoch 22: val_accuracy did not improve from 0.73397
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7529 - loss: 0.7602 - val_accuracy: 0.7199 - val_loss: 0.8785
# Epoch 23/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7426 - loss: 0.7892
# Epoch 23: val_accuracy improved from 0.73397 to 0.74295, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7426 - loss: 0.7892 - val_accuracy: 0.7429 - val_loss: 0.8242
# Epoch 24/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7518 - loss: 0.7668
# Epoch 24: val_accuracy did not improve from 0.74295
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7518 - loss: 0.7668 - val_accuracy: 0.7292 - val_loss: 0.8310
# Epoch 25/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7559 - loss: 0.7570
# Epoch 25: val_accuracy did not improve from 0.74295
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7559 - loss: 0.7570 - val_accuracy: 0.7321 - val_loss: 0.8533
# Epoch 26/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7543 - loss: 0.7537
# Epoch 26: val_accuracy did not improve from 0.74295
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.7543 - loss: 0.7537 - val_accuracy: 0.7404 - val_loss: 0.8118
# Epoch 27/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7613 - loss: 0.7265
# Epoch 27: val_accuracy improved from 0.74295 to 0.74359, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7613 - loss: 0.7265 - val_accuracy: 0.7436 - val_loss: 0.8127
# Epoch 28/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7601 - loss: 0.7300
# Epoch 28: val_accuracy did not improve from 0.74359
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7601 - loss: 0.7300 - val_accuracy: 0.7394 - val_loss: 0.8270
# Epoch 29/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7628 - loss: 0.7235
# Epoch 29: val_accuracy did not improve from 0.74359
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7628 - loss: 0.7235 - val_accuracy: 0.7356 - val_loss: 0.8228
# Epoch 30/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7672 - loss: 0.7170
# Epoch 30: val_accuracy improved from 0.74359 to 0.74519, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.7672 - loss: 0.7170 - val_accuracy: 0.7452 - val_loss: 0.8009
# Epoch 31/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7688 - loss: 0.7102
# Epoch 31: val_accuracy did not improve from 0.74519
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7688 - loss: 0.7102 - val_accuracy: 0.7292 - val_loss: 0.8822
# Epoch 32/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7512 - loss: 0.7435
# Epoch 32: val_accuracy did not improve from 0.74519
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7512 - loss: 0.7435 - val_accuracy: 0.7423 - val_loss: 0.7979
# Epoch 33/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7725 - loss: 0.7028
# Epoch 33: val_accuracy did not improve from 0.74519
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7725 - loss: 0.7028 - val_accuracy: 0.7407 - val_loss: 0.7965
# Epoch 34/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7726 - loss: 0.6976
# Epoch 34: val_accuracy improved from 0.74519 to 0.75096, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7726 - loss: 0.6976 - val_accuracy: 0.7510 - val_loss: 0.7852
# Epoch 35/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7758 - loss: 0.6876
# Epoch 35: val_accuracy improved from 0.75096 to 0.75128, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7758 - loss: 0.6876 - val_accuracy: 0.7513 - val_loss: 0.7776
# Epoch 36/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7758 - loss: 0.6839
# Epoch 36: val_accuracy did not improve from 0.75128
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7758 - loss: 0.6839 - val_accuracy: 0.7494 - val_loss: 0.7845
# Epoch 37/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7710 - loss: 0.6916
# Epoch 37: val_accuracy did not improve from 0.75128
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7711 - loss: 0.6915 - val_accuracy: 0.7484 - val_loss: 0.7797
# Epoch 38/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7728 - loss: 0.6946
# Epoch 38: val_accuracy did not improve from 0.75128
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7728 - loss: 0.6946 - val_accuracy: 0.7481 - val_loss: 0.7674
# Epoch 39/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7840 - loss: 0.6652
# Epoch 39: val_accuracy did not improve from 0.75128
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7840 - loss: 0.6653 - val_accuracy: 0.7500 - val_loss: 0.7796
# Epoch 40/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7752 - loss: 0.6847
# Epoch 40: val_accuracy did not improve from 0.75128
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7752 - loss: 0.6847 - val_accuracy: 0.7365 - val_loss: 0.7972
# Epoch 41/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7877 - loss: 0.6451
# Epoch 41: val_accuracy improved from 0.75128 to 0.76058, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7877 - loss: 0.6451 - val_accuracy: 0.7606 - val_loss: 0.7679
# Epoch 42/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7889 - loss: 0.6515
# Epoch 42: val_accuracy did not improve from 0.76058
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7889 - loss: 0.6515 - val_accuracy: 0.7558 - val_loss: 0.7648
# Epoch 43/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7905 - loss: 0.6424
# Epoch 43: val_accuracy did not improve from 0.76058
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7905 - loss: 0.6424 - val_accuracy: 0.7526 - val_loss: 0.7606
# Epoch 44/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7894 - loss: 0.6594
# Epoch 44: val_accuracy did not improve from 0.76058
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7894 - loss: 0.6594 - val_accuracy: 0.7567 - val_loss: 0.7615
# Epoch 45/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7926 - loss: 0.6298
# Epoch 45: val_accuracy improved from 0.76058 to 0.76506, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 227ms/step - accuracy: 0.7926 - loss: 0.6299 - val_accuracy: 0.7651 - val_loss: 0.7559
# Epoch 46/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7884 - loss: 0.6378
# Epoch 46: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7884 - loss: 0.6378 - val_accuracy: 0.7490 - val_loss: 0.7726
# Epoch 47/250
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7986 - loss: 0.6200
# Epoch 47: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7986 - loss: 0.6200 - val_accuracy: 0.7577 - val_loss: 0.7454
# Epoch 48/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8003 - loss: 0.6305
# Epoch 48: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8003 - loss: 0.6305 - val_accuracy: 0.7478 - val_loss: 0.7734
# Epoch 49/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7917 - loss: 0.6263
# Epoch 49: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7917 - loss: 0.6263 - val_accuracy: 0.7596 - val_loss: 0.7436
# Epoch 50/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7920 - loss: 0.6339
# Epoch 50: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7920 - loss: 0.6339 - val_accuracy: 0.7487 - val_loss: 0.7517
# Epoch 51/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7947 - loss: 0.6361
# Epoch 51: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.7947 - loss: 0.6361 - val_accuracy: 0.7619 - val_loss: 0.7432
# Epoch 52/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7982 - loss: 0.6124
# Epoch 52: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7982 - loss: 0.6124 - val_accuracy: 0.7593 - val_loss: 0.7384
# Epoch 53/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8100 - loss: 0.5921
# Epoch 53: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8100 - loss: 0.5921 - val_accuracy: 0.7522 - val_loss: 0.7641
# Epoch 54/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7987 - loss: 0.6119
# Epoch 54: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.7987 - loss: 0.6119 - val_accuracy: 0.7587 - val_loss: 0.7423
# Epoch 55/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8089 - loss: 0.5948
# Epoch 55: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8089 - loss: 0.5948 - val_accuracy: 0.7615 - val_loss: 0.7388
# Epoch 56/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8045 - loss: 0.6076
# Epoch 56: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8045 - loss: 0.6075 - val_accuracy: 0.7603 - val_loss: 0.7406
# Epoch 57/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8152 - loss: 0.5681
# Epoch 57: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8152 - loss: 0.5682 - val_accuracy: 0.7625 - val_loss: 0.7302
# Epoch 58/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8088 - loss: 0.5848
# Epoch 58: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8088 - loss: 0.5848 - val_accuracy: 0.7641 - val_loss: 0.7282
# Epoch 59/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8072 - loss: 0.6004
# Epoch 59: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8072 - loss: 0.6003 - val_accuracy: 0.7603 - val_loss: 0.7353
# Epoch 60/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8042 - loss: 0.5992
# Epoch 60: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8043 - loss: 0.5992 - val_accuracy: 0.7571 - val_loss: 0.7334
# Epoch 61/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8206 - loss: 0.5608
# Epoch 61: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8206 - loss: 0.5608 - val_accuracy: 0.7487 - val_loss: 0.7779
# Epoch 62/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8139 - loss: 0.5693
# Epoch 62: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8139 - loss: 0.5693 - val_accuracy: 0.7647 - val_loss: 0.7268
# Epoch 63/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8173 - loss: 0.5672
# Epoch 63: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 221ms/step - accuracy: 0.8173 - loss: 0.5672 - val_accuracy: 0.7641 - val_loss: 0.7251
# Epoch 64/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8228 - loss: 0.5406
# Epoch 64: val_accuracy did not improve from 0.76506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8228 - loss: 0.5406 - val_accuracy: 0.7622 - val_loss: 0.7191
# Epoch 65/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8161 - loss: 0.5518
# Epoch 65: val_accuracy improved from 0.76506 to 0.76538, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8161 - loss: 0.5518 - val_accuracy: 0.7654 - val_loss: 0.7121
# Epoch 66/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8190 - loss: 0.5516
# Epoch 66: val_accuracy did not improve from 0.76538
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8190 - loss: 0.5516 - val_accuracy: 0.7622 - val_loss: 0.7114
# Epoch 67/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8209 - loss: 0.5465
# Epoch 67: val_accuracy did not improve from 0.76538
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8209 - loss: 0.5465 - val_accuracy: 0.7631 - val_loss: 0.7146
# Epoch 68/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8270 - loss: 0.5309
# Epoch 68: val_accuracy improved from 0.76538 to 0.76667, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8270 - loss: 0.5309 - val_accuracy: 0.7667 - val_loss: 0.7106
# Epoch 69/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8182 - loss: 0.5480
# Epoch 69: val_accuracy improved from 0.76667 to 0.76891, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8182 - loss: 0.5480 - val_accuracy: 0.7689 - val_loss: 0.7197
# Epoch 70/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8251 - loss: 0.5334
# Epoch 70: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8251 - loss: 0.5334 - val_accuracy: 0.7577 - val_loss: 0.7385
# Epoch 71/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8217 - loss: 0.5575
# Epoch 71: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8217 - loss: 0.5574 - val_accuracy: 0.7654 - val_loss: 0.7087
# Epoch 72/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8286 - loss: 0.5425
# Epoch 72: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8286 - loss: 0.5425 - val_accuracy: 0.7619 - val_loss: 0.7108
# Epoch 73/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8256 - loss: 0.5324
# Epoch 73: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8256 - loss: 0.5324 - val_accuracy: 0.7679 - val_loss: 0.7121
# Epoch 74/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8353 - loss: 0.5121
# Epoch 74: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8353 - loss: 0.5121 - val_accuracy: 0.7683 - val_loss: 0.7101
# Epoch 75/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8292 - loss: 0.5302
# Epoch 75: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8293 - loss: 0.5302 - val_accuracy: 0.7673 - val_loss: 0.7124
# Epoch 76/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8337 - loss: 0.5115
# Epoch 76: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8337 - loss: 0.5115 - val_accuracy: 0.7663 - val_loss: 0.7096
# Epoch 77/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8332 - loss: 0.5033
# Epoch 77: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8332 - loss: 0.5034 - val_accuracy: 0.7590 - val_loss: 0.7202
# Epoch 78/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8321 - loss: 0.5182
# Epoch 78: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8321 - loss: 0.5182 - val_accuracy: 0.7628 - val_loss: 0.7177
# Epoch 79/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8309 - loss: 0.5254
# Epoch 79: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8309 - loss: 0.5254 - val_accuracy: 0.7676 - val_loss: 0.7052
# Epoch 80/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8331 - loss: 0.5075
# Epoch 80: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8331 - loss: 0.5075 - val_accuracy: 0.7593 - val_loss: 0.7132
# Epoch 81/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8345 - loss: 0.5107
# Epoch 81: val_accuracy did not improve from 0.76891
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8345 - loss: 0.5107 - val_accuracy: 0.7641 - val_loss: 0.7127
# Epoch 82/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8380 - loss: 0.5112
# Epoch 82: val_accuracy improved from 0.76891 to 0.77147, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8380 - loss: 0.5112 - val_accuracy: 0.7715 - val_loss: 0.6963
# Epoch 83/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8446 - loss: 0.4866
# Epoch 83: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8446 - loss: 0.4866 - val_accuracy: 0.7708 - val_loss: 0.7035
# Epoch 84/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8463 - loss: 0.4870
# Epoch 84: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8463 - loss: 0.4870 - val_accuracy: 0.7705 - val_loss: 0.6968
# Epoch 85/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8487 - loss: 0.4753
# Epoch 85: val_accuracy did not improve from 0.77147
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8487 - loss: 0.4753 - val_accuracy: 0.7705 - val_loss: 0.7011
# Epoch 86/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8460 - loss: 0.4854
# Epoch 86: val_accuracy improved from 0.77147 to 0.77308, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8460 - loss: 0.4854 - val_accuracy: 0.7731 - val_loss: 0.6974
# Epoch 87/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8445 - loss: 0.4802
# Epoch 87: val_accuracy did not improve from 0.77308
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8445 - loss: 0.4803 - val_accuracy: 0.7692 - val_loss: 0.6965
# Epoch 88/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8473 - loss: 0.4776
# Epoch 88: val_accuracy did not improve from 0.77308
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8473 - loss: 0.4776 - val_accuracy: 0.7699 - val_loss: 0.6970
# Epoch 89/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8470 - loss: 0.4766
# Epoch 89: val_accuracy did not improve from 0.77308
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8470 - loss: 0.4766 - val_accuracy: 0.7731 - val_loss: 0.6912
# Epoch 90/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8486 - loss: 0.4750
# Epoch 90: val_accuracy did not improve from 0.77308
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8485 - loss: 0.4750 - val_accuracy: 0.7679 - val_loss: 0.6966
# Epoch 91/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8497 - loss: 0.4656
# Epoch 91: val_accuracy did not improve from 0.77308
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8497 - loss: 0.4656 - val_accuracy: 0.7625 - val_loss: 0.6992
# Epoch 92/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8488 - loss: 0.4826
# Epoch 92: val_accuracy improved from 0.77308 to 0.77660, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8488 - loss: 0.4826 - val_accuracy: 0.7766 - val_loss: 0.6940
# Epoch 93/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8501 - loss: 0.4780
# Epoch 93: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8501 - loss: 0.4780 - val_accuracy: 0.7766 - val_loss: 0.6933
# Epoch 94/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8506 - loss: 0.4662
# Epoch 94: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8506 - loss: 0.4662 - val_accuracy: 0.7753 - val_loss: 0.6910
# Epoch 95/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8507 - loss: 0.4653
# Epoch 95: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8507 - loss: 0.4653 - val_accuracy: 0.7747 - val_loss: 0.6894
# Epoch 96/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8556 - loss: 0.4643
# Epoch 96: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8555 - loss: 0.4643 - val_accuracy: 0.7766 - val_loss: 0.6947
# Epoch 97/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8488 - loss: 0.4756
# Epoch 97: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8488 - loss: 0.4756 - val_accuracy: 0.7718 - val_loss: 0.6924
# Epoch 98/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8519 - loss: 0.4563
# Epoch 98: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8519 - loss: 0.4563 - val_accuracy: 0.7753 - val_loss: 0.6863
# Epoch 99/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8550 - loss: 0.4563
# Epoch 99: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8550 - loss: 0.4563 - val_accuracy: 0.7744 - val_loss: 0.6862
# Epoch 100/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8563 - loss: 0.4591
# Epoch 100: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8563 - loss: 0.4591 - val_accuracy: 0.7702 - val_loss: 0.6867
# Epoch 101/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8601 - loss: 0.4434
# Epoch 101: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8601 - loss: 0.4434 - val_accuracy: 0.7712 - val_loss: 0.6918
# Epoch 102/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8610 - loss: 0.4407
# Epoch 102: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8610 - loss: 0.4408 - val_accuracy: 0.7753 - val_loss: 0.6954
# Epoch 103/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8619 - loss: 0.4371
# Epoch 103: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8619 - loss: 0.4371 - val_accuracy: 0.7728 - val_loss: 0.6871
# Epoch 104/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8628 - loss: 0.4331
# Epoch 104: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8628 - loss: 0.4331 - val_accuracy: 0.7750 - val_loss: 0.6889
# Epoch 105/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8605 - loss: 0.4460
# Epoch 105: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8605 - loss: 0.4460 - val_accuracy: 0.7734 - val_loss: 0.6834
# Epoch 106/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8624 - loss: 0.4397
# Epoch 106: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8624 - loss: 0.4397 - val_accuracy: 0.7731 - val_loss: 0.6911
# Epoch 107/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8634 - loss: 0.4397
# Epoch 107: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8634 - loss: 0.4397 - val_accuracy: 0.7712 - val_loss: 0.6897
# Epoch 108/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8655 - loss: 0.4243
# Epoch 108: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8655 - loss: 0.4243 - val_accuracy: 0.7740 - val_loss: 0.6841
# Epoch 109/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8662 - loss: 0.4212
# Epoch 109: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8662 - loss: 0.4212 - val_accuracy: 0.7753 - val_loss: 0.7015
# Epoch 110/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8675 - loss: 0.4186
# Epoch 110: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8674 - loss: 0.4186 - val_accuracy: 0.7744 - val_loss: 0.6860
# Epoch 111/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8668 - loss: 0.4251
# Epoch 111: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8668 - loss: 0.4251 - val_accuracy: 0.7740 - val_loss: 0.6948
# Epoch 112/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8681 - loss: 0.4140
# Epoch 112: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8681 - loss: 0.4140 - val_accuracy: 0.7718 - val_loss: 0.6827
# Epoch 113/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8705 - loss: 0.4215
# Epoch 113: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8705 - loss: 0.4215 - val_accuracy: 0.7766 - val_loss: 0.6827
# Epoch 114/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8675 - loss: 0.4187
# Epoch 114: val_accuracy did not improve from 0.77660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8675 - loss: 0.4187 - val_accuracy: 0.7763 - val_loss: 0.6827
# Epoch 115/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8770 - loss: 0.4028
# Epoch 115: val_accuracy improved from 0.77660 to 0.78429, saving model to best_model.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 89s 226ms/step - accuracy: 0.8770 - loss: 0.4029 - val_accuracy: 0.7843 - val_loss: 0.6947
# Epoch 116/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8791 - loss: 0.4011
# Epoch 116: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8791 - loss: 0.4012 - val_accuracy: 0.7705 - val_loss: 0.6983
# Epoch 117/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8751 - loss: 0.4011
# Epoch 117: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8751 - loss: 0.4011 - val_accuracy: 0.7785 - val_loss: 0.6882
# Epoch 118/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8757 - loss: 0.4085
# Epoch 118: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8757 - loss: 0.4085 - val_accuracy: 0.7824 - val_loss: 0.6799
# Epoch 119/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8741 - loss: 0.4055
# Epoch 119: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8741 - loss: 0.4056 - val_accuracy: 0.7737 - val_loss: 0.6854
# Epoch 120/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8754 - loss: 0.3991
# Epoch 120: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8754 - loss: 0.3991 - val_accuracy: 0.7782 - val_loss: 0.6877
# Epoch 121/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8734 - loss: 0.4077
# Epoch 121: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8734 - loss: 0.4077 - val_accuracy: 0.7779 - val_loss: 0.6830
# Epoch 122/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8723 - loss: 0.4106
# Epoch 122: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8723 - loss: 0.4106 - val_accuracy: 0.7744 - val_loss: 0.6828
# Epoch 123/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8747 - loss: 0.3969
# Epoch 123: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8747 - loss: 0.3969 - val_accuracy: 0.7782 - val_loss: 0.6840
# Epoch 124/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8828 - loss: 0.3825
# Epoch 124: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8828 - loss: 0.3825 - val_accuracy: 0.7763 - val_loss: 0.6842
# Epoch 125/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8852 - loss: 0.3797
# Epoch 125: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8852 - loss: 0.3798 - val_accuracy: 0.7756 - val_loss: 0.6884
# Epoch 126/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8821 - loss: 0.3866
# Epoch 126: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8821 - loss: 0.3866 - val_accuracy: 0.7821 - val_loss: 0.6849
# Epoch 127/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8782 - loss: 0.3894
# Epoch 127: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8782 - loss: 0.3894 - val_accuracy: 0.7798 - val_loss: 0.6836
# Epoch 128/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8819 - loss: 0.3803
# Epoch 128: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8819 - loss: 0.3803 - val_accuracy: 0.7766 - val_loss: 0.6871
# Epoch 129/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8805 - loss: 0.3839
# Epoch 129: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8805 - loss: 0.3839 - val_accuracy: 0.7824 - val_loss: 0.6800
# Epoch 130/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8838 - loss: 0.3693
# Epoch 130: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8838 - loss: 0.3693 - val_accuracy: 0.7804 - val_loss: 0.6801
# Epoch 131/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8849 - loss: 0.3668
# Epoch 131: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8849 - loss: 0.3668 - val_accuracy: 0.7779 - val_loss: 0.6814
# Epoch 132/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8867 - loss: 0.3720
# Epoch 132: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8867 - loss: 0.3720 - val_accuracy: 0.7779 - val_loss: 0.6795
# Epoch 133/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8907 - loss: 0.3634
# Epoch 133: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 87s 220ms/step - accuracy: 0.8907 - loss: 0.3634 - val_accuracy: 0.7718 - val_loss: 0.6867
# Epoch 134/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8871 - loss: 0.3687
# Epoch 134: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8871 - loss: 0.3687 - val_accuracy: 0.7660 - val_loss: 0.7134
# Epoch 135/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8766 - loss: 0.3856
# Epoch 135: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8767 - loss: 0.3855 - val_accuracy: 0.7830 - val_loss: 0.6816
# Epoch 136/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8842 - loss: 0.3690
# Epoch 136: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8842 - loss: 0.3690 - val_accuracy: 0.7721 - val_loss: 0.6862
# Epoch 137/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8907 - loss: 0.3462
# Epoch 137: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8907 - loss: 0.3463 - val_accuracy: 0.7776 - val_loss: 0.6918
# Epoch 138/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8918 - loss: 0.3578
# Epoch 138: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8917 - loss: 0.3579 - val_accuracy: 0.7772 - val_loss: 0.6870
# Epoch 139/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8899 - loss: 0.3575
# Epoch 139: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8899 - loss: 0.3575 - val_accuracy: 0.7792 - val_loss: 0.6914
# Epoch 140/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8908 - loss: 0.3587
# Epoch 140: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8908 - loss: 0.3587 - val_accuracy: 0.7628 - val_loss: 0.7243
# Epoch 141/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8823 - loss: 0.3732
# Epoch 141: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8824 - loss: 0.3732 - val_accuracy: 0.7760 - val_loss: 0.6827
# Epoch 142/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8955 - loss: 0.3416
# Epoch 142: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 219ms/step - accuracy: 0.8955 - loss: 0.3416 - val_accuracy: 0.7795 - val_loss: 0.6783
# Epoch 143/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8911 - loss: 0.3522
# Epoch 143: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8911 - loss: 0.3522 - val_accuracy: 0.7776 - val_loss: 0.6789
# Epoch 144/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8995 - loss: 0.3452
# Epoch 144: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 219ms/step - accuracy: 0.8995 - loss: 0.3453 - val_accuracy: 0.7792 - val_loss: 0.6863
# Epoch 145/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8943 - loss: 0.3400
# Epoch 145: val_accuracy did not improve from 0.78429
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 220ms/step - accuracy: 0.8943 - loss: 0.3400 - val_accuracy: 0.7824 - val_loss: 0.6862
# Epoch 145: early stopping
# Restoring model weights from the end of the best epoch: 115.
# 2025-01-23 14:19:40.392472: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.5554, expected 3.07265
# 2025-01-23 14:19:40.392542: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 3.13778, expected 2.65504
# 2025-01-23 14:19:40.392552: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 3.34289, expected 2.86015
# 2025-01-23 14:19:40.392561: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 181: 3.72137, expected 3.23862
# 2025-01-23 14:19:40.392570: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 198: 3.32536, expected 2.84261
# 2025-01-23 14:19:40.392579: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 199: 3.81774, expected 3.335
# 2025-01-23 14:19:40.392587: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 223: 2.84685, expected 2.36411
# 2025-01-23 14:19:40.392609: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3808: 3.78401, expected 3.30126
# 2025-01-23 14:19:40.392622: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4927: 3.65987, expected 3.17712
# 2025-01-23 14:19:40.392633: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5600: 3.81283, expected 3.33008
# 2025-01-23 14:19:40.458420: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[29,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[29,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 14:19:40.458467: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 14:19:40.458476: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 14:19:40.458483: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 14:19:40.458491: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 14:19:40.458508: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2025-01-23 14:19:41.439802: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.5554, expected 3.07265
# 2025-01-23 14:19:41.439862: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 3.13778, expected 2.65504
# 2025-01-23 14:19:41.439872: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 3.34289, expected 2.86015
# 2025-01-23 14:19:41.439881: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 181: 3.72137, expected 3.23862
# 2025-01-23 14:19:41.439889: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 198: 3.32536, expected 2.84261
# 2025-01-23 14:19:41.439897: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 199: 3.81774, expected 3.335
# 2025-01-23 14:19:41.439905: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 223: 2.84685, expected 2.36411
# 2025-01-23 14:19:41.439928: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3808: 3.78401, expected 3.30126
# 2025-01-23 14:19:41.439941: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4927: 3.65987, expected 3.17712
# 2025-01-23 14:19:41.439951: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5600: 3.81283, expected 3.33008
# 2025-01-23 14:19:41.505343: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[29,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[29,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2025-01-23 14:19:41.505399: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2025-01-23 14:19:41.505408: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2025-01-23 14:19:41.505415: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2025-01-23 14:19:41.505422: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2025-01-23 14:19:41.505439: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# Test Loss: 0.7452, Test Accuracy: 75.78%
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
#   2/122 ━━━━━━━━━━━━━━━━━━━━ 18s 151ms/step
# W0000 00:00:1737641998.525264     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 28s 201ms/step
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#           Cell       0.57      0.53      0.55       391
#     Cell-Multi       0.46      0.40      0.43       283
#       Cracking       0.70      0.66      0.68       186
#          Diode       0.81      0.74      0.77       300
#    Diode-Multi       0.45      0.23      0.31        43
#     No-Anomaly       0.86      0.95      0.90      1915
# Offline-Module       0.66      0.49      0.56       172
#      Shadowing       0.71      0.57      0.63       220
#        Soiling       0.33      0.27      0.30        30
#     Vegetation       0.66      0.66      0.66       361
#
#       accuracy                           0.76      3901
#      macro avg       0.62      0.55      0.58      3901
#   weighted avg       0.74      0.76      0.75      3901
#
# Weighted Precision: 0.7442
# Weighted Recall: 0.7578
